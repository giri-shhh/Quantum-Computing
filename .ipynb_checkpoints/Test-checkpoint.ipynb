# %% [raw]
# ---
# title: Hello 🌍🪐
# description: Hello app
# show-cde: True
# params:
#     planet:
#         input: select
#         label: Please select a planet
#         value: Earth
#         choices: [Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, Neptune]
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot
import mercury as mr
import seaborn as sns

# %%
app = mr.App(title='Test', description='Test description')
# Out:
# mercury.App

# %%
hue = 'smoker'
tips=sns.load_dataset('tips')

mr.Text(label='Test', value='Test')
# Out:
# mercury.Text
# mercury.Text

# %%
sns.pairplot(tips, hue=hue);

# %%
df = pd.read_csv('italy-covid-daywise.csv')

# %%
df = df.tail(100)

# %%
pyplot.plot(range(0, len(df['new_cases'])), df['new_cases']);
